# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/diabetes_prediction_dataset.csv.zip')
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x='diabetes',data=df)
# Out:
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
sns.countplot(x='diabetes',data=df,hue='hypertension',color='green')
# Out:
# <ipython-input-44-7d73b696abfd>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:green'` for the same effect.
#
#   sns.countplot(x='diabetes',data=df,hue='hypertension',color='green')
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
sns.countplot(x='diabetes',data=df,hue='heart_disease',color='yellow')
# Out:
# <ipython-input-45-511ff49b3bac>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:yellow'` for the same effect.
#
#   sns.countplot(x='diabetes',data=df,hue='heart_disease',color='yellow')
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
sns.countplot(x='diabetes',data=df,hue='smoking_history',color='yellow')
# Out:
# <ipython-input-46-01f26c04a4dc>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:yellow'` for the same effect.
#
#   sns.countplot(x='diabetes',data=df,hue='smoking_history',color='yellow')
# <Axes: xlabel='diabetes', ylabel='count'>

# %%
df.drop(['gender'],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['smoking_history']=lb.fit_transform(df['smoking_history'])
df
# Out:
#         age  hypertension  heart_disease  smoking_history    bmi  HbA1c_level  \
# 0      80.0             0              1                4  25.19          6.6
# 1      54.0             0              0                0  27.32          6.6
# 2      28.0             0              0                4  27.32          5.7
# 3      36.0             0              0                1  23.45          5.0
# 4      76.0             1              1                1  20.14          4.8
# ...     ...           ...            ...              ...    ...          ...
# 99995  80.0             0              0                0  27.32          6.2
# 99996   2.0             0              0                0  17.37          6.5
# 99997  66.0             0              0                3  27.83          5.7
# 99998  24.0             0              0                4  35.42          4.0
# 99999  57.0             0              0                1  22.43          6.6
#
# ...

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[ 80.  ,   0.  ,   1.  , ...,  25.19,   6.6 , 140.  ],
#        [ 54.  ,   0.  ,   0.  , ...,  27.32,   6.6 ,  80.  ],
#        [ 28.  ,   0.  ,   0.  , ...,  27.32,   5.7 , 158.  ],
#        ...,
#        [ 66.  ,   0.  ,   0.  , ...,  27.83,   5.7 , 155.  ],
#        [ 24.  ,   0.  ,   0.  , ...,  35.42,   4.  , 100.  ],
#        [ 57.  ,   0.  ,   0.  , ...,  22.43,   6.6 ,  90.  ]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi',
#        'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
for i in['age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi',
       'HbA1c_level', 'blood_glucose_level', 'diabetes']:
 plt.figure(figsize=(5,5))
 sns.boxplot(df[i], color='green')
 plt.xlabel(i)
 plt.ylabel('Range')

# %%
def iqr_method(df,variables):
  q1=df[variables].quantile(0.25)
  q3=df[variables].quantile(0.75)
  iqr=q3-q1
  upper=q3+(1.5*iqr)
  lower=q1-(1.5*iqr)
  return lower,upper

# %%
lst=['age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi',
       'HbA1c_level', 'blood_glucose_level', 'diabetes']

# %%
for i in lst:
  print(i)
  lower_lim,upper_lim=iqr_method(df,i)
  print('lower limit = ',lower_lim)
  print('upper limit = ',upper_lim)
  df[i]=np.where(df[i]>upper_lim,upper_lim,
                   np.where(df[i]<lower_lim,lower_lim,df[i]))
# Out:
# age
# lower limit =  -30.0
# upper limit =  114.0
# hypertension
# lower limit =  0.0
# upper limit =  0.0
# heart_disease
# lower limit =  0.0
# upper limit =  0.0
# smoking_history
# lower limit =  -6.0
# upper limit =  10.0
# bmi
# lower limit =  14.705
# upper limit =  38.504999999999995
# HbA1c_level
# lower limit =  2.6999999999999993
# upper limit =  8.3
# blood_glucose_level
# lower limit =  11.5
# upper limit =  247.5
# diabetes
# lower limit =  0.0
# upper limit =  0.0

# %%
for i in['age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi',
       'HbA1c_level', 'blood_glucose_level', 'diabetes']:
 plt.figure(figsize=(5,5))
 sns.boxplot(df[i], color='green')
 plt.xlabel(i)
 plt.ylabel('Range')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree  import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

knn=KNeighborsClassifier(n_neighbors=7)
tree=DecisionTreeClassifier(criterion='entropy')
ada=AdaBoostClassifier(n_estimators=50,random_state=42)
clas=RandomForestClassifier(n_estimators=10,criterion='entropy')
lst=[knn,tree,ada,clas]

# %%
for i in lst:
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print("Model is ",i)
  print("y_pred is",y_pred)
  print("*"*100)
  print('confusion_matrix is',confusion_matrix(y_test,y_pred))
  print("*"*100)
  print("Accuracy score is",accuracy_score(y_test,y_pred))
  print("*"*100)
  print('classifictaion report is',classification_report(y_test,y_pred))
# Out:
# Model is  KNeighborsClassifier(n_neighbors=7)
# y_pred is [0 0 0 ... 0 0 0]
# ****************************************************************************************************
# confusion_matrix is [[27318   135]
#  [ 1287  1260]]
# ****************************************************************************************************
# Accuracy score is 0.9526
# ****************************************************************************************************
# classifictaion report is               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.97     27453
#            1       0.90      0.49      0.64      2547
#
#     accuracy                           0.95     30000
#    macro avg       0.93      0.74      0.81     30000
# weighted avg       0.95      0.95      0.95     30000
#
# Model is  DecisionTreeClassifier(criterion='entropy')
# y_pred is [0 0 0 ... 0 1 0]
# ...
